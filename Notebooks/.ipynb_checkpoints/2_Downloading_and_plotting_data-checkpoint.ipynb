# %% [markdown]
# ### Previous Session
#
# ####   Step1 : Download the script to local directory of `fraction.py` from
# https://drive.google.com/file/d/1GOHrcX_OurRz7z_qInAsmAY2IaDbTNAf/view?usp=sharing
#
# ####   Step2 : make the script executable
# ```
# chmod +x test.py
# ```
# ####   Step3 : Run the tests
# ```
# ./test.py -f1 1/3 -f2 2/3
# ./test.py -f1 5/3 -f2 2/4
# ./test.py -f1 23/45 -f2 4/5
# ```

# %%
from astropy.coordinates import SkyCoord
SkyCoord(24,23, unit='degree').to_string('hmsdms')
# Out:
# '01h36m00s +23d00m00s'

# %%
from matplotlib import pyplot as plt
import numpy as np
import random
from astropy.io import fits
from astropy.wcs import WCS

# %% [markdown]
# ## Downloading Data

# %% [markdown]
# ### Astroquery

# %% [markdown]
# #### Installation

# %%
# !pip install astroquery
# Out:
# Requirement already satisfied: astroquery in /usr/local/lib/python3.10/dist-packages (0.4.7)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.25.2)
# Requirement already satisfied: astropy>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from astroquery) (5.3.4)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.10/dist-packages (from astroquery) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.8 in /usr/local/lib/python3.10/dist-packages (from astroquery) (4.12.3)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.1)
# Requirement already satisfied: keyring>=15.0 in /usr/lib/python3/dist-packages (from astroquery) (23.5.0)
# Requirement already satisfied: pyvo>=1.1 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.5.2)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.2.1->astroquery) (2.0.1.4)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.2.1->astroquery) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.2.1->astroquery) (24.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.8->astroquery) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (2024.6.2)

# %% [markdown]
# #### Example

# %%
from astroquery.skyview import SkyView

# %%
dir(SkyView)
# Out:
# ['URL',
#  '__abstractmethods__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_cache_location',
#  '_default_form_values',
#  '_download_file',
#  '_generate_payload',
#  '_get_default_form_values',
#  '_last_query',
#  '_parse_response',
#  '_request',
#  '_response_hook',
#  '_session',
#  '_submit_form',
#  '_survey_dict',
#  '_valid_surveys',
#  '_validate_surveys',
#  'cache_location',
#  'clear_cache',
#  'get_image_list',
#  'get_images',
#  'get_images_async',
#  'list_surveys',
#  'name',
#  'reset_cache_location',
#  'survey_dict']

# %%
# SkyView.survey_dict

# %%
# all_surveys = SkyView.survey_dict

# %%
filelist = SkyView.get_image_list(position="M87", survey=['SDSSi', 'SDSSr', 'SDSSg'])

# %%
filelist
# Out:
# ['https://skyview.gsfc.nasa.gov/tempspace/fits/skv20367903974075_1.fits',
#  'https://skyview.gsfc.nasa.gov/tempspace/fits/skv20367903974075_2.fits',
#  'https://skyview.gsfc.nasa.gov/tempspace/fits/skv20367903974075_3.fits']

# %% [markdown]
# ### Manupulating FITS file

# %%
from astropy.io import fits

hdu1 = fits.open(filelist[0])
hdu1

# %%
hdu1.info()
# Out:
# Filename: /root/.astropy/cache/download/url/35988dadfb22760a84d43f394bd72f8d/contents
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     126   (300, 300)   float32

# %%
hdu1[0]

# %%
len(hdu1[0].header)
# Out:
# 126

# %%
hdu1[0].data
# Out:
# array([[0.7402344 , 0.8095703 , 0.81640625, ..., 0.6582031 , 0.6953125 ,
#         0.6953125 ],
#        [0.74609375, 0.89160156, 0.7783203 , ..., 0.7783203 , 0.6826172 ,
#         0.6386719 ],
#        [0.7529297 , 0.74609375, 0.72753906, ..., 0.6640625 , 0.7402344 ,
#         0.70214844],
#        ...,
#        [0.7011719 , 0.68847656, 0.5996094 , ..., 0.8720703 , 0.7578125 ,
#         0.80859375],
#        [0.65722656, 0.6689453 , 0.7519531 , ..., 0.859375  , 0.80859375,
#         0.7138672 ],
#        [0.65625   , 0.70703125, 0.6816406 , ..., 0.8466797 , 0.8027344 ,
#         0.8027344 ]], dtype='>f4')

# %%
import numpy as np

np.shape(hdu1[0].data)
# Out:
# (300, 300)

# %% [markdown]
# ### Plotting Data

# %%
from matplotlib import pyplot as plt
plt.plot()
# plt.plot([1,2,3,4,5], [2,4,6,8,10])
# Out:
# []

# %%
plt.imshow(hdu1[0].data)

# %%
ax0 = plt.subplot()
ax0.imshow(hdu1[0].data, cmap='gray')

# %% [markdown]
# ### Scaling the brightness

# %%
ax0 = plt.subplot()
img1_log = np.log(hdu1[0].data)
ax0.imshow(img1_log, cmap='gray')


# can you spot the problems?

# %%
ax0 = plt.subplot()
img1_log = np.log(hdu1[0].data)
ax0.imshow(img1_log, cmap='gray', origin='lower')

# %% [markdown]
# ### Projection for World Coordinate System

# %%
from astropy.wcs import WCS
wcs = WCS(hdu1[0].header)

# %%
ax0 = plt.subplot(projection=wcs)

img1_log = np.log(hdu1[0].data)
ax0.imshow(img1_log, cmap='gray', origin='lower')

# %%
x=y = np.arange(0,255)
y = y/255
ax0 = plt.subplot(111)
ax0.plot(x,y)
ax0.set_xlabel('Input')
ax0.set_ylabel('Output')
# Out:
# Text(0, 0.5, 'Output')

# %%
y = np.arange(0,255)
y = np.log(y)
ax0 = plt.subplot(111)
ax0.plot(x,y)
ax0.set_xlabel('Input')
ax0.set_ylabel('Output')
# Out:
# <ipython-input-63-8cfa61e3361e>:2: RuntimeWarning: divide by zero encountered in log
#   y = np.log(y)
# Text(0, 0.5, 'Output')

# %%
x=y = np.arange(0,255)
y = np.sqrt(y)
ax0 = plt.subplot(111)
ax0.plot(x,y)
ax0.set_xlabel('Input')
ax0.set_ylabel('Output')
# Out:
# Text(0, 0.5, 'Output')

# %% [markdown]
# ## Summary so far
#
# - Download data using astroquery's `SkyView`
# - Access the 2D array of the FITS image using `astropy.io.fits`
# - 2D array of image is plotted using `matlotlib`
# - Image scaling like log is used to improve the image brightness when there is high dynamic range
# - `astropy.wcs.WCS` is used to correct the projection in the plotted image

# %%
px_data = [random.randint(1, 256) for _ in range(9000)]

# %%
# import random

# x=y = np.arange(0,255)
# ax0 = plt.subplot(111)
# ax0.plot(x,y)
# ax0.set_xlabel('Input')
# ax0.set_ylabel('Output')


# # print(data, )
# pax = ax0.hist(px_data, bins=50, alpha=0.5, color='gray')

# %%
def get_img(fitsfile):
  hdu = fits.open(fitsfile)[0]
  img = hdu.data
  return img

def pl_img(hdu, cmap='gray', vmin=None, vmax=None, scale=None):
  """
  """
  img = hdu.data
  if scale:
    if scale=='log':
      img = scale_log(img)
    elif scale=='sqrt':
      img = scale_sqrt(img)

  if not vmin: vmin = np.min(img)
  if not vmax: vmax = np.max(img)
  wcs = WCS(hdu.header)
  ax0 = plt.subplot(projection=wcs)
  ax0.imshow(img, cmap=cmap )

def scale_log(img):
  return np.log(abs(img))

def scale_sqrt(img):
  return np.sqrt(img)

# %% [markdown]
# ### P1: Write a method using `astroquery` to download the data
# given the name of the target and survey name,
# finally plot utilising the methods above.

# %%
# your code here

# %% [markdown]
# ### P2: Download the data using `astropy.coordinates`

# %%
# your code here

from astropy.coordinates import SkyCoord

c = SkyCoord.from_name("M66")
c

list_hdu = SkyView.get_images(position=c, survey='DSS2 Red')
list_hdu
# Out:
# [[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7bbdc1f6d990>]]

# %%
def plot_byname(name, svy):
  c = SkyCoord.from_name(name)
  list_hdu = SkyView.get_images(position=c, survey=svy)
  hdu = list_hdu[0][0]
  pl_img(hdu)

plot_byname("M66", "DSS2 Red")

# %% [markdown]
# #### ZScaleInterval
#
# To make a cut with the limiting values

# %%
from astropy.visualization import ZScaleInterval
z = ZScaleInterval(contrast=0.1)

# %%
img_data = get_img(filelist[0])
vmin, vmax = z.get_limits(img_data)
print(vmin, vmax)

# %%
pl_img(filelist[0], vmin=vmin, vmax=vmax)

# %%
z = ZScaleInterval(contrast=0.1)
img_data = scale_log(get_img(filelist[0]))
vmin, vmax = z.get_limits(img_data)
print(vmin, vmax)

pl_img(filelist[0], vmin=vmin, vmax=vmax, scale='log')

# %% [markdown]
# ### P3: Try downloading the VLA data

# %%
# your code here

# %%
# pl_img(hdu[0],)
# cmin = 0.05
# lvl = 4
# c = d = hdu[0].data
# lvlc = np.arange(cmin, c.max(),((c.max() - cmin)/lvl))
# print(lvlc)
# plt.contour(d, lvlc, colors='white')

# %% [markdown]
# ### P4: Plot the contours of Radio data e.g VLA 1.4 GHz with the optical image e.g SDSS

# %%
# your code here

# %% [markdown]
# ### For Future : Downloading data using pyvo
# because some recent survey data are not yet available through SkyView
